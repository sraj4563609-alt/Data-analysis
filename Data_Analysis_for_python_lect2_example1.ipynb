# %%
# List of sales in each region
sales = [420, 455, 610, 300, 175]

# List of region names
regions = ["North", "South", "East", "West", "Central"]

# Find the total sales
total = sum(sales)

# Find the average sales
average = total / len(sales)

# Find the lowest sales value
lowest_sales = min(sales)

# Find the position (index) of the lowest sales
lowest_index = sales.index(lowest_sales)

# Find the region with the lowest sales
lowest_region = regions[lowest_index]

# Display the results
print("Total sales:", total)
print("Average sales:", average)
print("Lowest performing region:", lowest_region)
# Out:
# Total sales: 1960
# Average sales: 392.0
# Lowest performing region: Central
