# %% [markdown]
# <a href="https://colab.research.google.com/github/sraj4563609-alt/Data-analysis/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a dictionary with student's name, age, and marks
student = {"Name": "Amit", "Age": 21, "Marks": 85}

# Print the dictionary
print(student)

# Print the type of the dictionary
print(type(student))
# Out:
# {'Name': 'Amit', 'Age': 21, 'Marks': 85}
# <class 'dict'>
